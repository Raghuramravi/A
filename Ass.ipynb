# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghuramravi/A/blob/main/Ass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install missingno

# %%
import missingno as msno
import matplotlib.pyplot as plt

msno.matrix(df)
plt.title("Missing Data Matrix")
plt.show()

# %%
print(df.isnull().sum())

print((df.isnull().sum() / len(df)) * 100)

df[df.isnull().any(axis=1)]
# Out:
# index              0
# name               0
# date_of_birth      0
# height             0
# weight             0
# spike              0
# block              0
# position_number    0
# country            0
# dtype: int64
# index              0.0
# name               0.0
# date_of_birth      0.0
# height             0.0
# weight             0.0
# spike              0.0
# block              0.0
# position_number    0.0
# country            0.0
# dtype: float64
# Empty DataFrame
# Columns: [index, name, date_of_birth, height, weight, spike, block, position_number, country]
# Index: []

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Raghuramravi/b/main/clean_data.csv"
df = pd.read_csv(url)
df.isnull().sum()
(df.isnull().sum() / len(df)) * 100
df[df.isnull().any(axis=1)]
df.isnull().sum().sum()
# !pip install missingno
import missingno as msno
import matplotlib.pyplot as plt

msno.matrix(df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/Raghuramravi/b/main/clean_data.csv"
df = pd.read_csv(url)

display(df[['name', 'country', 'height', 'weight', 'position_number']].head())

players_by_country = df['country'].value_counts().reset_index()
players_by_country.columns = ['Country', 'Number_of_Players']

display(players_by_country.head())

plt.figure(figsize=(10,6))
sns.barplot(data=players_by_country.head(10), x='Number_of_Players', y='Country', palette='cubehelix')
plt.title("🌍 Top 10 Countries by Number of Players")
plt.xlabel("Number of Players")
plt.ylabel("Country")
plt.tight_layout()
plt.show()
# Out:
#                     name  country  height  weight  position_number
# 0     Angelina Lazarenko       23     193      80                3
# 1       Svetlana Serbina       23     182      71                1
# 2  Ekaterina Shkurikhina       23     190      72                2
# 3     Kristina Kurnosova       23     176      62                6
# 4     Ekaterina Novikova       23     181      70                1
#    Country  Number_of_Players
# 0        9                 39
# 1       23                 36
# 2       10                 36
# 3       24                 36
# 4       29                 36
# /tmp/ipython-input-2-4219463634.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=players_by_country.head(10), x='Number_of_Players', y='Country', palette='cubehelix')
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(data=players_by_country.head(10), x='Number_of_Players', y='Country', palette='cubehelix')
plt.title("🌍 Top 10 Countries by Number of Players")
plt.xlabel("Number of Players")
plt.ylabel("Country")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-5-3055986315.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=players_by_country.head(10), x='Number_of_Players', y='Country', palette='cubehelix')
# /tmp/ipython-input-5-3055986315.py:9: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
players_by_country = df['country'].value_counts().reset_index()
players_by_country.columns = ['Country', 'Number_of_Players']
players_by_country.head(10)
# Out:
#    Country  Number_of_Players
# 0        9                 39
# 1       23                 36
# 2       10                 36
# 3       24                 36
# 4       29                 36
# 5       19                 36
# 6       31                 36
# 7        5                 36
# 8       15                 36
# 9       30                 36

# %%
df[['name', 'country', 'height', 'weight', 'position_number']].head(10)
# Out:
#                      name  country  height  weight  position_number
# 0      Angelina Lazarenko       23     193      80                3
# 1        Svetlana Serbina       23     182      71                1
# 2   Ekaterina Shkurikhina       23     190      72                2
# 3      Kristina Kurnosova       23     176      62                6
# 4      Ekaterina Novikova       23     181      70                1
# 5      Victoria Zhurbenko       23     186      67                3
# 6     Angelina Sperskaite       23     188      72                2
# 7      Anastasiia Barchuk       23     187      78                3
# 8  Anastasiia Cheremisina       23     187      80                2
# 9           Anna Lazareva       23     190      67                4

# %%
df[['name', 'country', 'height', 'weight', 'position_number']].head(10)
# Out:
#                      name  country  height  weight  position_number
# 0      Angelina Lazarenko       23     193      80                3
# 1        Svetlana Serbina       23     182      71                1
# 2   Ekaterina Shkurikhina       23     190      72                2
# 3      Kristina Kurnosova       23     176      62                6
# 4      Ekaterina Novikova       23     181      70                1
# 5      Victoria Zhurbenko       23     186      67                3
# 6     Angelina Sperskaite       23     188      72                2
# 7      Anastasiia Barchuk       23     187      78                3
# 8  Anastasiia Cheremisina       23     187      80                2
# 9           Anna Lazareva       23     190      67                4

# %%
players_by_country = df['country'].value_counts().reset_index()
players_by_country.columns = ['Country', 'Number_of_Players']
display(players_by_country.head(10))
# Out:
#    Country  Number_of_Players
# 0        9                 39
# 1       23                 36
# 2       10                 36
# 3       24                 36
# 4       29                 36
# 5       19                 36
# 6       31                 36
# 7        5                 36
# 8       15                 36
# 9       30                 36

# %%
avg_by_country = df.groupby('country')[['height', 'weight']].mean().reset_index()
avg_by_country = avg_by_country.sort_values(by='height', ascending=False)
display(avg_by_country.head(10))
# Out:
#     country      height     weight
# 6        23  186.833333  72.250000
# 0         5  185.416667  69.666667
# 3        15  185.250000  74.833333
# 11       31  182.750000  68.583333
# 7        24  182.000000  66.666667
# 8        26  181.750000  67.083333
# 2        10  181.583333  72.666667
# 1         9  179.846154  67.076923
# 10       30  178.833333  64.416667
# 5        19  177.416667  72.166667

# %%
position_counts = df['position_number'].value_counts().reset_index()
position_counts.columns = ['Position_Number', 'Player_Count']
display(position_counts)
# Out:
#    Position_Number  Player_Count
# 0                2           144
# 1                3           108
# 2                1            75
# 3                4            63
# 4                6            42

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(data=avg_by_country.head(10), x='height', y='country', palette='crest')
plt.title("🏐 Top 10 Countries by Average Player Height")
plt.xlabel("Average Height (cm)")
plt.ylabel("Country")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-11-3398862603.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_by_country.head(10), x='height', y='country', palette='crest')
# /tmp/ipython-input-11-3398862603.py:9: UserWarning: Glyph 127952 (\N{VOLLEYBALL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127952 (\N{VOLLEYBALL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
